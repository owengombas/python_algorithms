# %%
from lib.heap import Heap, heapsort
from IPython.display import display

# %%
heap = Heap([1,45, 12, 31, 3, 8, 0, 23, 1, 3, 9, 2, 4, 5, 6, 7, 8, 9, 10, 11])
heap.insert(24)
heap.insert(84)
heap.insert(2)
heap.to_graphviz()

# %%
for i in range(heap.size):
    print(heap.extract_min())
    display(heap.to_graphviz())
# Out:
# 0
# 1
# 1
# 2
# 2
# 3
# 3
# 4
# 5
# 6
# 7
# 8
# 8
# 9
# 9
# 10
# 11
# 12
# 23
# 24
# 31
# 45
# 84

# %%
array = [84, 5, 17, 3, 10, 6, 19, 22, 9]
sorted_array, heap = heapsort(array)
display(heap.to_graphviz())
print(sorted_array)
# Out:
# [84, 22, 19, 17, 10, 9, 6, 5, 3]
